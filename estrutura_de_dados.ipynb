# %%
#Criando uma lista chamada Animais
animais = [1, 2, 3]
animais
# Out:
# [1, 2, 3]

# %%
#Colocando numeros e strings dentro da lista
animais = ['Gato', 'Cachorro', 1, 2, 3.3]
animais
# Out:
# ['Gato', 'Cachorro', 1, 2, 3.3]

# %%
#Imprimindo primeiro elemento da lista

# %%
animais[0]
# Out:
# 'Gato'

# %%
#Substituindo um elemento da lista
animais[2] = 'Papagaio'
animais
# Out:
# ['Gato', 'Cachorro', 'Papagaio', 2, 3.3]

# %%
#Removendo elemento da lista

# %%
animais.remove('Gato')
animais
# Out:
# ['Cachorro', 2, 3.3]

# %%
#Vendo quantos elementos tem na lista
len(animais)
# Out:
# 3

# %%
#Vendo se elemento esta na lista
'Gato' in animais
# Out:
# False

# %%
lista = [100, 24, 222, 1988]

# %%
#Verifica o valor maxímo na lista
max(lista)
# Out:
# 1988

# %%
#Verifica o valor minímo da lista
min(lista)
# Out:
# 24

# %%
#Adicionar um elemento na lista
animais.append('Cobra')
animais
# Out:
# ['Cachorro', 2, 3.3, 'Cobra', 'Cobra']

# %%
#adicionar mais de uma variável de uma vez
animais.extend(["Veado","Boi"])

# %%
animais
# Out:
# ['Cachorro', 2, 3.3, 'Cobra', 'Veado', 'Boi']

# %%
animais.remove("Cobra")

# %%
#Contar quantas vezes a variavel aparece
animais.count("Cobra")
# Out:
# 1

# %%
#Ordena os valores da lista
lista.sort()
lista
# Out:
# [24, 100, 222, 1988]

# %%
#Tuplas
tp = ("Maça", "Banana", 111, 222)

# %%
tp
# Out:
# ('Maça', 'Banana', 111, 222)

# %%
#Retorna qualquer elemento da mesma foram que lista
tp[2]
# Out:
# 111

# %%
#A diferença é que as tuplas sao imutáveis ou seja nao pode ser alterada
#tp[2] = "Feijão"

# %%
#Dicionários
dc = {"Maça":20, "Banana":10, "Laranja": 22, "Pitanga":44}
dc
# Out:
# {'Maça': 20, 'Banana': 10, 'Laranja': 22, 'Pitanga': 44}

# %%
#Acessando o valor de um dicionário através da chave
dc["Maça"]
# Out:
# 20

# %%
#Atualizando o valor da banana
dc["Banana"] = 45
dc["Banana"]
# Out:
# 45

# %%
#Retornando todas as chaves do dicionário
dc.keys()
# Out:
# dict_keys(['Maça', 'Banana', 'Laranja', 'Pitanga'])

# %%
#Retornando todos os valores do dicionário
dc.values()
# Out:
# dict_values([20, 45, 22, 44])

# %%
#Verifica se já existe uma chave no dicionário e se não existir inseri no dicionario
dc.setdefault("Limão", 50)
# Out:
# 50

# %%
dc
# Out:
# {'Maça': 20, 'Banana': 45, 'Laranja': 22, 'Pitanga': 44, 'Limão': 50}
